# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 231.4169 - y1_output_loss: 109.2139 - y2_output_loss: 120.2299 - y1_output_root_mean_squared_error: 10.4984 - y2_output_root_mean_squared_error: 11.0091 - val_loss: 32.9667 - val_y1_output_loss: 17.6158 - val_y2_output_loss: 14.5522 - val_y1_output_root_mean_squared_error: 4.2547 - val_y2_output_root_mean_squared_error: 3.8554
# Epoch 2/500
# 614/614 [==============================] - 0s 210us/sample - loss: 34.9286 - y1_output_loss: 12.0084 - y2_output_loss: 22.7782 - y1_output_root_mean_squared_error: 3.4740 - y2_output_root_mean_squared_error: 4.7812 - val_loss: 47.5745 - val_y1_output_loss: 17.6561 - val_y2_output_loss: 29.2972 - val_y1_output_root_mean_squared_error: 4.2550 - val_y2_output_root_mean_squared_error: 5.4285
# Epoch 3/500
# 614/614 [==============================] - 0s 222us/sample - loss: 28.7808 - y1_output_loss: 10.2333 - y2_output_loss: 18.3043 - y1_output_root_mean_squared_error: 3.2121 - y2_output_root_mean_squared_error: 4.2969 - val_loss: 27.2519 - val_y1_output_loss: 13.2146 - val_y2_output_loss: 13.8136 - val_y1_output_root_mean_squared_error: 3.6676 - val_y2_output_root_mean_squared_error: 3.7149
# Epoch 4/500
# 614/614 [==============================] - 0s 230us/sample - loss: 24.3604 - y1_output_loss: 9.3323 - y2_output_loss: 15.2452 - y1_output_root_mean_squared_error: 3.0298 - y2_output_root_mean_squared_error: 3.8963 - val_loss: 22.2102 - val_y1_output_loss: 11.0771 - val_y2_output_loss: 11.0008 - val_y1_output_root_mean_squared_error: 3.3427 - val_y2_output_root_mean_squared_error: 3.3221
# Epoch 5/500
# 614/614 [==============================] - 0s 210us/sample - loss: 24.5854 - y1_output_loss: 9.0672 - y2_output_loss: 15.7121 - y1_output_root_mean_squared_error: 3.0070 - y2_output_root_mean_squared_error: 3.9425 - val_loss: 30.2674 - val_y1_output_loss: 11.5864 - val_y2_output_loss: 18.6060 - val_y1_output_root_mean_squared_error: 3.4407 - val_y2_output_root_mean_squared_error: 4.2929
# Epoch 6/500
# 614/614 [==============================] - 0s 204us/sample - loss: 22.5871 - y1_output_loss: 8.5008 - y2_output_loss: 13.9809 - y1_output_root_mean_squared_error: 2.9217 - y2_output_root_mean_squared_error: 3.7484 - val_loss: 27.3729 - val_y1_output_loss: 12.3675 - val_y2_output_loss: 14.9058 - val_y1_output_root_mean_squared_error: 3.5516 - val_y2_output_root_mean_squared_error: 3.8418
# Epoch 7/500
# 614/614 [==============================] - 0s 214us/sample - loss: 20.3069 - y1_output_loss: 7.9599 - y2_output_loss: 12.7570 - y1_output_root_mean_squared_error: 2.8140 - y2_output_root_mean_squared_error: 3.5197 - val_loss: 34.6784 - val_y1_output_loss: 9.4327 - val_y2_output_loss: 24.2091 - val_y1_output_root_mean_squared_error: 3.1123 - val_y2_output_root_mean_squared_error: 4.9992
# Epoch 8/500
# 614/614 [==============================] - 0s 216us/sample - loss: 21.5628 - y1_output_loss: 7.7713 - y2_output_loss: 13.7177 - y1_output_root_mean_squared_error: 2.7820 - y2_output_root_mean_squared_error: 3.7180 - val_loss: 20.7928 - val_y1_output_loss: 10.4306 - val_y2_output_loss: 10.0196 - val_y1_output_root_mean_squared_error: 3.2596 - val_y2_output_root_mean_squared_error: 3.1887
# Epoch 9/500
# 614/614 [==============================] - 0s 204us/sample - loss: 20.6012 - y1_output_loss: 7.6195 - y2_output_loss: 12.8874 - y1_output_root_mean_squared_error: 2.7713 - y2_output_root_mean_squared_error: 3.5946 - val_loss: 30.0934 - val_y1_output_loss: 10.2816 - val_y2_output_loss: 19.1608 - val_y1_output_root_mean_squared_error: 3.2327 - val_y2_output_root_mean_squared_error: 4.4320
# Epoch 10/500
# 614/614 [==============================] - 0s 215us/sample - loss: 19.5533 - y1_output_loss: 7.2130 - y2_output_loss: 12.2527 - y1_output_root_mean_squared_error: 2.6815 - y2_output_root_mean_squared_error: 3.5161 - val_loss: 20.4414 - val_y1_output_loss: 9.8198 - val_y2_output_loss: 10.3295 - val_y1_output_root_mean_squared_error: 3.1667 - val_y2_output_root_mean_squared_error: 3.2269
# Epoch 11/500
# 614/614 [==============================] - 0s 214us/sample - loss: 19.2425 - y1_output_loss: 6.9498 - y2_output_loss: 12.1893 - y1_output_root_mean_squared_error: 2.6431 - y2_output_root_mean_squared_error: 3.5010 - val_loss: 17.0970 - val_y1_output_loss: 8.4376 - val_y2_output_loss: 8.5802 - val_y1_output_root_mean_squared_error: 2.9376 - val_y2_output_root_mean_squared_error: 2.9099
# Epoch 12/500
# 614/614 [==============================] - 0s 239us/sample - loss: 18.3224 - y1_output_loss: 6.9245 - y2_output_loss: 11.4489 - y1_output_root_mean_squared_error: 2.6294 - y2_output_root_mean_squared_error: 3.3777 - val_loss: 15.2937 - val_y1_output_loss: 7.5961 - val_y2_output_loss: 7.5237 - val_y1_output_root_mean_squared_error: 2.7893 - val_y2_output_root_mean_squared_error: 2.7411
# Epoch 13/500
# 614/614 [==============================] - 0s 219us/sample - loss: 16.8866 - y1_output_loss: 6.7303 - y2_output_loss: 10.0794 - y1_output_root_mean_squared_error: 2.6006 - y2_output_root_mean_squared_error: 3.1817 - val_loss: 22.2090 - val_y1_output_loss: 10.4192 - val_y2_output_loss: 11.8182 - val_y1_output_root_mean_squared_error: 3.2579 - val_y2_output_root_mean_squared_error: 3.4052
# Epoch 14/500
# 614/614 [==============================] - 0s 199us/sample - loss: 20.6707 - y1_output_loss: 7.1209 - y2_output_loss: 13.4867 - y1_output_root_mean_squared_error: 2.6772 - y2_output_root_mean_squared_error: 3.6747 - val_loss: 21.6467 - val_y1_output_loss: 8.1149 - val_y2_output_loss: 12.8550 - val_y1_output_root_mean_squared_error: 2.8915 - val_y2_output_root_mean_squared_error: 3.6450
# Epoch 15/500
# 614/614 [==============================] - 0s 222us/sample - loss: 17.0255 - y1_output_loss: 6.2094 - y2_output_loss: 10.8363 - y1_output_root_mean_squared_error: 2.4824 - y2_output_root_mean_squared_error: 3.2959 - val_loss: 18.4576 - val_y1_output_loss: 8.7979 - val_y2_output_loss: 9.3910 - val_y1_output_root_mean_squared_error: 3.0103 - val_y2_output_root_mean_squared_error: 3.0652
# Epoch 16/500
# 614/614 [==============================] - 0s 230us/sample - loss: 15.6327 - y1_output_loss: 6.1043 - y2_output_loss: 9.5228 - y1_output_root_mean_squared_error: 2.4602 - y2_output_root_mean_squared_error: 3.0952 - val_loss: 15.3805 - val_y1_output_loss: 7.0725 - val_y2_output_loss: 8.0884 - val_y1_output_root_mean_squared_error: 2.6918 - val_y2_output_root_mean_squared_error: 2.8522
# Epoch 17/500
# 614/614 [==============================] - 0s 218us/sample - loss: 18.3676 - y1_output_loss: 6.4777 - y2_output_loss: 11.7335 - y1_output_root_mean_squared_error: 2.5555 - y2_output_root_mean_squared_error: 3.4405 - val_loss: 15.1764 - val_y1_output_loss: 7.1705 - val_y2_output_loss: 7.9095 - val_y1_output_root_mean_squared_error: 2.6994 - val_y2_output_root_mean_squared_error: 2.8089
# Epoch 18/500
# 614/614 [==============================] - 0s 226us/sample - loss: 14.3520 - y1_output_loss: 5.2743 - y2_output_loss: 8.9665 - y1_output_root_mean_squared_error: 2.3063 - y2_output_root_mean_squared_error: 3.0055 - val_loss: 12.9145 - val_y1_output_loss: 6.1904 - val_y2_output_loss: 6.5206 - val_y1_output_root_mean_squared_error: 2.5207 - val_y2_output_root_mean_squared_error: 2.5614
# Epoch 19/500
# 614/614 [==============================] - 0s 187us/sample - loss: 18.1175 - y1_output_loss: 6.0552 - y2_output_loss: 11.9573 - y1_output_root_mean_squared_error: 2.4681 - y2_output_root_mean_squared_error: 3.4678 - val_loss: 13.3196 - val_y1_output_loss: 6.4941 - val_y2_output_loss: 6.7547 - val_y1_output_root_mean_squared_error: 2.5751 - val_y2_output_root_mean_squared_error: 2.5862
# Epoch 20/500
# 614/614 [==============================] - 0s 190us/sample - loss: 14.2562 - y1_output_loss: 5.3560 - y2_output_loss: 8.7832 - y1_output_root_mean_squared_error: 2.3246 - y2_output_root_mean_squared_error: 2.9753 - val_loss: 13.2519 - val_y1_output_loss: 6.1141 - val_y2_output_loss: 7.0244 - val_y1_output_root_mean_squared_error: 2.4955 - val_y2_output_root_mean_squared_error: 2.6503
# Epoch 21/500
# 614/614 [==============================] - 0s 185us/sample - loss: 16.2833 - y1_output_loss: 5.5415 - y2_output_loss: 10.6052 - y1_output_root_mean_squared_error: 2.3626 - y2_output_root_mean_squared_error: 3.2713 - val_loss: 12.6499 - val_y1_output_loss: 5.7835 - val_y2_output_loss: 6.7030 - val_y1_output_root_mean_squared_error: 2.4356 - val_y2_output_root_mean_squared_error: 2.5919
# Epoch 22/500
# 614/614 [==============================] - 0s 199us/sample - loss: 16.2461 - y1_output_loss: 5.7383 - y2_output_loss: 10.3903 - y1_output_root_mean_squared_error: 2.4041 - y2_output_root_mean_squared_error: 3.2352 - val_loss: 12.1245 - val_y1_output_loss: 5.4099 - val_y2_output_loss: 6.4261 - val_y1_output_root_mean_squared_error: 2.3614 - val_y2_output_root_mean_squared_error: 2.5589
# Epoch 23/500
# 614/614 [==============================] - 0s 188us/sample - loss: 11.9443 - y1_output_loss: 4.5732 - y2_output_loss: 7.2653 - y1_output_root_mean_squared_error: 2.1472 - y2_output_root_mean_squared_error: 2.7081 - val_loss: 10.7619 - val_y1_output_loss: 4.7481 - val_y2_output_loss: 5.9565 - val_y1_output_root_mean_squared_error: 2.2066 - val_y2_output_root_mean_squared_error: 2.4275
# Epoch 24/500
# 614/614 [==============================] - 0s 191us/sample - loss: 11.9298 - y1_output_loss: 4.4888 - y2_output_loss: 7.4026 - y1_output_root_mean_squared_error: 2.1234 - y2_output_root_mean_squared_error: 2.7241 - val_loss: 11.2735 - val_y1_output_loss: 4.6880 - val_y2_output_loss: 6.3252 - val_y1_output_root_mean_squared_error: 2.1956 - val_y2_output_root_mean_squared_error: 2.5402
# Epoch 25/500
# 614/614 [==============================] - 0s 187us/sample - loss: 11.6052 - y1_output_loss: 4.3060 - y2_output_loss: 7.3088 - y1_output_root_mean_squared_error: 2.0795 - y2_output_root_mean_squared_error: 2.6983 - val_loss: 22.2239 - val_y1_output_loss: 5.9264 - val_y2_output_loss: 15.5267 - val_y1_output_root_mean_squared_error: 2.4741 - val_y2_output_root_mean_squared_error: 4.0128
# Epoch 26/500
# 614/614 [==============================] - 0s 190us/sample - loss: 12.0276 - y1_output_loss: 4.0541 - y2_output_loss: 7.9182 - y1_output_root_mean_squared_error: 2.0174 - y2_output_root_mean_squared_error: 2.8209 - val_loss: 12.8327 - val_y1_output_loss: 5.4044 - val_y2_output_loss: 7.0302 - val_y1_output_root_mean_squared_error: 2.3675 - val_y2_output_root_mean_squared_error: 2.6884
# Epoch 27/500
# 614/614 [==============================] - 0s 186us/sample - loss: 11.0362 - y1_output_loss: 4.0643 - y2_output_loss: 7.0520 - y1_output_root_mean_squared_error: 2.0168 - y2_output_root_mean_squared_error: 2.6398 - val_loss: 54.5112 - val_y1_output_loss: 10.0613 - val_y2_output_loss: 42.6580 - val_y1_output_root_mean_squared_error: 3.2206 - val_y2_output_root_mean_squared_error: 6.6437
# Epoch 28/500
# 614/614 [==============================] - 0s 191us/sample - loss: 13.8028 - y1_output_loss: 4.5697 - y2_output_loss: 9.3879 - y1_output_root_mean_squared_error: 2.1296 - y2_output_root_mean_squared_error: 3.0443 - val_loss: 45.6118 - val_y1_output_loss: 9.3904 - val_y2_output_loss: 34.7939 - val_y1_output_root_mean_squared_error: 3.1080 - val_y2_output_root_mean_squared_error: 5.9960
# Epoch 29/500
# 614/614 [==============================] - 0s 193us/sample - loss: 14.6928 - y1_output_loss: 4.7323 - y2_output_loss: 9.8938 - y1_output_root_mean_squared_error: 2.1712 - y2_output_root_mean_squared_error: 3.1589 - val_loss: 10.4551 - val_y1_output_loss: 4.3692 - val_y2_output_loss: 6.1112 - val_y1_output_root_mean_squared_error: 2.1128 - val_y2_output_root_mean_squared_error: 2.4477
# Epoch 30/500
# 614/614 [==============================] - 0s 197us/sample - loss: 10.6078 - y1_output_loss: 3.7086 - y2_output_loss: 6.9067 - y1_output_root_mean_squared_error: 1.9331 - y2_output_root_mean_squared_error: 2.6213 - val_loss: 18.4090 - val_y1_output_loss: 4.7281 - val_y2_output_loss: 13.1884 - val_y1_output_root_mean_squared_error: 2.1926 - val_y2_output_root_mean_squared_error: 3.6880
# Epoch 31/500
# 614/614 [==============================] - 0s 187us/sample - loss: 8.8698 - y1_output_loss: 3.2255 - y2_output_loss: 5.6552 - y1_output_root_mean_squared_error: 1.7915 - y2_output_root_mean_squared_error: 2.3792 - val_loss: 13.2084 - val_y1_output_loss: 5.0424 - val_y2_output_loss: 8.2948 - val_y1_output_root_mean_squared_error: 2.2627 - val_y2_output_root_mean_squared_error: 2.8440
# Epoch 32/500
# 614/614 [==============================] - 0s 249us/sample - loss: 9.8353 - y1_output_loss: 3.5894 - y2_output_loss: 6.2110 - y1_output_root_mean_squared_error: 1.8954 - y2_output_root_mean_squared_error: 2.4986 - val_loss: 10.5985 - val_y1_output_loss: 3.9056 - val_y2_output_loss: 6.6282 - val_y1_output_root_mean_squared_error: 1.9943 - val_y2_output_root_mean_squared_error: 2.5732
# Epoch 33/500
# 614/614 [==============================] - 0s 221us/sample - loss: 9.9899 - y1_output_loss: 3.4330 - y2_output_loss: 6.6237 - y1_output_root_mean_squared_error: 1.8531 - y2_output_root_mean_squared_error: 2.5605 - val_loss: 10.8681 - val_y1_output_loss: 3.1463 - val_y2_output_loss: 7.3708 - val_y1_output_root_mean_squared_error: 1.8007 - val_y2_output_root_mean_squared_error: 2.7615
# Epoch 34/500
# 614/614 [==============================] - 0s 230us/sample - loss: 8.5505 - y1_output_loss: 2.7290 - y2_output_loss: 5.7783 - y1_output_root_mean_squared_error: 1.6532 - y2_output_root_mean_squared_error: 2.4119 - val_loss: 15.6154 - val_y1_output_loss: 4.9135 - val_y2_output_loss: 10.1593 - val_y1_output_root_mean_squared_error: 2.2570 - val_y2_output_root_mean_squared_error: 3.2437
# Epoch 35/500
# 614/614 [==============================] - 0s 230us/sample - loss: 10.0112 - y1_output_loss: 3.3458 - y2_output_loss: 6.5813 - y1_output_root_mean_squared_error: 1.8347 - y2_output_root_mean_squared_error: 2.5778 - val_loss: 8.5005 - val_y1_output_loss: 2.8054 - val_y2_output_loss: 5.5202 - val_y1_output_root_mean_squared_error: 1.6976 - val_y2_output_root_mean_squared_error: 2.3703
# Epoch 36/500
# 614/614 [==============================] - 0s 204us/sample - loss: 7.3302 - y1_output_loss: 2.7644 - y2_output_loss: 4.6618 - y1_output_root_mean_squared_error: 1.6475 - y2_output_root_mean_squared_error: 2.1485 - val_loss: 29.5241 - val_y1_output_loss: 6.7454 - val_y2_output_loss: 21.7004 - val_y1_output_root_mean_squared_error: 2.6452 - val_y2_output_root_mean_squared_error: 4.7463
# Epoch 37/500
# 614/614 [==============================] - 0s 268us/sample - loss: 9.4018 - y1_output_loss: 3.3271 - y2_output_loss: 6.0128 - y1_output_root_mean_squared_error: 1.8304 - y2_output_root_mean_squared_error: 2.4600 - val_loss: 11.1056 - val_y1_output_loss: 3.2926 - val_y2_output_loss: 7.5873 - val_y1_output_root_mean_squared_error: 1.8284 - val_y2_output_root_mean_squared_error: 2.7861
# Epoch 38/500
# 614/614 [==============================] - 0s 242us/sample - loss: 8.6025 - y1_output_loss: 2.7976 - y2_output_loss: 5.7717 - y1_output_root_mean_squared_error: 1.6795 - y2_output_root_mean_squared_error: 2.4045 - val_loss: 8.4689 - val_y1_output_loss: 2.8389 - val_y2_output_loss: 5.4524 - val_y1_output_root_mean_squared_error: 1.7075 - val_y2_output_root_mean_squared_error: 2.3565
# Epoch 39/500
# 614/614 [==============================] - 0s 281us/sample - loss: 8.5342 - y1_output_loss: 2.9329 - y2_output_loss: 5.6134 - y1_output_root_mean_squared_error: 1.7148 - y2_output_root_mean_squared_error: 2.3651 - val_loss: 22.4469 - val_y1_output_loss: 3.8405 - val_y2_output_loss: 17.8014 - val_y1_output_root_mean_squared_error: 1.9935 - val_y2_output_root_mean_squared_error: 4.2980
# Epoch 40/500
# 614/614 [==============================] - 0s 224us/sample - loss: 8.1035 - y1_output_loss: 2.7712 - y2_output_loss: 5.3384 - y1_output_root_mean_squared_error: 1.6702 - y2_output_root_mean_squared_error: 2.3052 - val_loss: 9.0274 - val_y1_output_loss: 2.9902 - val_y2_output_loss: 5.7958 - val_y1_output_root_mean_squared_error: 1.7552 - val_y2_output_root_mean_squared_error: 2.4386
# Epoch 41/500
# 614/614 [==============================] - 0s 245us/sample - loss: 7.6313 - y1_output_loss: 2.5915 - y2_output_loss: 4.9931 - y1_output_root_mean_squared_error: 1.6136 - y2_output_root_mean_squared_error: 2.2423 - val_loss: 10.6020 - val_y1_output_loss: 4.1373 - val_y2_output_loss: 6.5152 - val_y1_output_root_mean_squared_error: 2.0490 - val_y2_output_root_mean_squared_error: 2.5306
# Epoch 42/500
# 614/614 [==============================] - 0s 209us/sample - loss: 7.6792 - y1_output_loss: 2.4766 - y2_output_loss: 5.1394 - y1_output_root_mean_squared_error: 1.5802 - y2_output_root_mean_squared_error: 2.2764 - val_loss: 7.1747 - val_y1_output_loss: 2.4421 - val_y2_output_loss: 4.6789 - val_y1_output_root_mean_squared_error: 1.5791 - val_y2_output_root_mean_squared_error: 2.1636
# Epoch 43/500
# 614/614 [==============================] - 0s 217us/sample - loss: 6.9214 - y1_output_loss: 2.3800 - y2_output_loss: 4.5537 - y1_output_root_mean_squared_error: 1.5320 - y2_output_root_mean_squared_error: 2.1388 - val_loss: 8.3282 - val_y1_output_loss: 2.6085 - val_y2_output_loss: 5.4451 - val_y1_output_root_mean_squared_error: 1.6429 - val_y2_output_root_mean_squared_error: 2.3725
# Epoch 44/500
# 614/614 [==============================] - 0s 193us/sample - loss: 7.8893 - y1_output_loss: 2.6574 - y2_output_loss: 5.1755 - y1_output_root_mean_squared_error: 1.6349 - y2_output_root_mean_squared_error: 2.2840 - val_loss: 7.4101 - val_y1_output_loss: 2.2130 - val_y2_output_loss: 5.0698 - val_y1_output_root_mean_squared_error: 1.5030 - val_y2_output_root_mean_squared_error: 2.2696
# Epoch 45/500
# 614/614 [==============================] - 0s 188us/sample - loss: 8.0126 - y1_output_loss: 2.7365 - y2_output_loss: 5.2388 - y1_output_root_mean_squared_error: 1.6525 - y2_output_root_mean_squared_error: 2.2983 - val_loss: 7.0355 - val_y1_output_loss: 2.7345 - val_y2_output_loss: 4.2504 - val_y1_output_root_mean_squared_error: 1.6742 - val_y2_output_root_mean_squared_error: 2.0573
# Epoch 46/500
# 614/614 [==============================] - 0s 202us/sample - loss: 7.6821 - y1_output_loss: 2.5364 - y2_output_loss: 5.0906 - y1_output_root_mean_squared_error: 1.5959 - y2_output_root_mean_squared_error: 2.2661 - val_loss: 7.9863 - val_y1_output_loss: 2.8239 - val_y2_output_loss: 4.9412 - val_y1_output_root_mean_squared_error: 1.7092 - val_y2_output_root_mean_squared_error: 2.2506
# Epoch 47/500
# 614/614 [==============================] - 0s 196us/sample - loss: 7.2331 - y1_output_loss: 2.4649 - y2_output_loss: 4.7371 - y1_output_root_mean_squared_error: 1.5673 - y2_output_root_mean_squared_error: 2.1856 - val_loss: 7.5221 - val_y1_output_loss: 2.3673 - val_y2_output_loss: 4.9981 - val_y1_output_root_mean_squared_error: 1.5581 - val_y2_output_root_mean_squared_error: 2.2571
# Epoch 48/500
# 614/614 [==============================] - 0s 212us/sample - loss: 8.5521 - y1_output_loss: 3.0165 - y2_output_loss: 5.5700 - y1_output_root_mean_squared_error: 1.7347 - y2_output_root_mean_squared_error: 2.3543 - val_loss: 9.5742 - val_y1_output_loss: 3.6933 - val_y2_output_loss: 5.6555 - val_y1_output_root_mean_squared_error: 1.9473 - val_y2_output_root_mean_squared_error: 2.4046
# Epoch 49/500
# 614/614 [==============================] - 0s 191us/sample - loss: 8.0326 - y1_output_loss: 2.5261 - y2_output_loss: 5.5023 - y1_output_root_mean_squared_error: 1.5878 - y2_output_root_mean_squared_error: 2.3477 - val_loss: 11.4879 - val_y1_output_loss: 4.9933 - val_y2_output_loss: 6.2502 - val_y1_output_root_mean_squared_error: 2.2599 - val_y2_output_root_mean_squared_error: 2.5261
# Epoch 50/500
# 614/614 [==============================] - 0s 184us/sample - loss: 8.1542 - y1_output_loss: 2.8800 - y2_output_loss: 5.2870 - y1_output_root_mean_squared_error: 1.6883 - y2_output_root_mean_squared_error: 2.3030 - val_loss: 9.1686 - val_y1_output_loss: 2.4693 - val_y2_output_loss: 6.4812 - val_y1_output_root_mean_squared_error: 1.5847 - val_y2_output_root_mean_squared_error: 2.5802
# Epoch 51/500
# 614/614 [==============================] - 0s 245us/sample - loss: 7.0085 - y1_output_loss: 2.4293 - y2_output_loss: 4.6823 - y1_output_root_mean_squared_error: 1.5467 - y2_output_root_mean_squared_error: 2.1485 - val_loss: 19.0785 - val_y1_output_loss: 3.9665 - val_y2_output_loss: 14.4286 - val_y1_output_root_mean_squared_error: 2.0242 - val_y2_output_root_mean_squared_error: 3.8706
# Epoch 52/500
# 614/614 [==============================] - 0s 234us/sample - loss: 7.9440 - y1_output_loss: 2.5205 - y2_output_loss: 5.3573 - y1_output_root_mean_squared_error: 1.5927 - y2_output_root_mean_squared_error: 2.3253 - val_loss: 7.0107 - val_y1_output_loss: 2.7715 - val_y2_output_loss: 4.1524 - val_y1_output_root_mean_squared_error: 1.6862 - val_y2_output_root_mean_squared_error: 2.0415
# Epoch 53/500
# 614/614 [==============================] - 0s 252us/sample - loss: 7.7792 - y1_output_loss: 2.6255 - y2_output_loss: 5.1056 - y1_output_root_mean_squared_error: 1.6274 - y2_output_root_mean_squared_error: 2.2651 - val_loss: 8.5809 - val_y1_output_loss: 2.4344 - val_y2_output_loss: 5.8757 - val_y1_output_root_mean_squared_error: 1.5862 - val_y2_output_root_mean_squared_error: 2.4627
# Epoch 54/500
# 614/614 [==============================] - 0s 219us/sample - loss: 6.6937 - y1_output_loss: 2.2481 - y2_output_loss: 4.4397 - y1_output_root_mean_squared_error: 1.4932 - y2_output_root_mean_squared_error: 2.1128 - val_loss: 7.7680 - val_y1_output_loss: 3.2726 - val_y2_output_loss: 4.4288 - val_y1_output_root_mean_squared_error: 1.8258 - val_y2_output_root_mean_squared_error: 2.1058
# Epoch 55/500
# 614/614 [==============================] - 0s 252us/sample - loss: 6.2391 - y1_output_loss: 2.1599 - y2_output_loss: 4.0268 - y1_output_root_mean_squared_error: 1.4749 - y2_output_root_mean_squared_error: 2.0159 - val_loss: 6.4868 - val_y1_output_loss: 2.4075 - val_y2_output_loss: 4.0788 - val_y1_output_root_mean_squared_error: 1.5654 - val_y2_output_root_mean_squared_error: 2.0090
# Epoch 56/500
# 614/614 [==============================] - 0s 254us/sample - loss: 7.3716 - y1_output_loss: 2.3662 - y2_output_loss: 4.9789 - y1_output_root_mean_squared_error: 1.5447 - y2_output_root_mean_squared_error: 2.2328 - val_loss: 10.0636 - val_y1_output_loss: 2.6486 - val_y2_output_loss: 7.0809 - val_y1_output_root_mean_squared_error: 1.6526 - val_y2_output_root_mean_squared_error: 2.7079
# Epoch 57/500
# 614/614 [==============================] - 0s 239us/sample - loss: 6.1931 - y1_output_loss: 2.0933 - y2_output_loss: 4.1337 - y1_output_root_mean_squared_error: 1.4483 - y2_output_root_mean_squared_error: 2.0237 - val_loss: 10.3152 - val_y1_output_loss: 3.7595 - val_y2_output_loss: 6.6353 - val_y1_output_root_mean_squared_error: 1.9502 - val_y2_output_root_mean_squared_error: 2.5518
# Epoch 58/500
# 614/614 [==============================] - 0s 203us/sample - loss: 5.8388 - y1_output_loss: 1.9385 - y2_output_loss: 3.8569 - y1_output_root_mean_squared_error: 1.3975 - y2_output_root_mean_squared_error: 1.9713 - val_loss: 5.9430 - val_y1_output_loss: 2.0281 - val_y2_output_loss: 3.9317 - val_y1_output_root_mean_squared_error: 1.4242 - val_y2_output_root_mean_squared_error: 1.9786
# Epoch 59/500
# 614/614 [==============================] - 0s 238us/sample - loss: 5.6542 - y1_output_loss: 1.9269 - y2_output_loss: 3.6860 - y1_output_root_mean_squared_error: 1.3941 - y2_output_root_mean_squared_error: 1.9263 - val_loss: 6.5278 - val_y1_output_loss: 2.4897 - val_y2_output_loss: 4.0408 - val_y1_output_root_mean_squared_error: 1.5898 - val_y2_output_root_mean_squared_error: 2.0001
# Epoch 60/500
# 614/614 [==============================] - 0s 254us/sample - loss: 6.7599 - y1_output_loss: 2.2182 - y2_output_loss: 4.5283 - y1_output_root_mean_squared_error: 1.4875 - y2_output_root_mean_squared_error: 2.1324 - val_loss: 6.5286 - val_y1_output_loss: 2.8092 - val_y2_output_loss: 3.6094 - val_y1_output_root_mean_squared_error: 1.6955 - val_y2_output_root_mean_squared_error: 1.9116
# Epoch 61/500
# 614/614 [==============================] - 0s 207us/sample - loss: 7.4448 - y1_output_loss: 2.3599 - y2_output_loss: 5.1612 - y1_output_root_mean_squared_error: 1.5279 - y2_output_root_mean_squared_error: 2.2606 - val_loss: 16.9925 - val_y1_output_loss: 6.0316 - val_y2_output_loss: 10.5033 - val_y1_output_root_mean_squared_error: 2.4879 - val_y2_output_root_mean_squared_error: 3.2868
# Epoch 62/500
# 614/614 [==============================] - 0s 254us/sample - loss: 8.1681 - y1_output_loss: 2.5706 - y2_output_loss: 5.6295 - y1_output_root_mean_squared_error: 1.6072 - y2_output_root_mean_squared_error: 2.3632 - val_loss: 11.3685 - val_y1_output_loss: 2.8016 - val_y2_output_loss: 8.2113 - val_y1_output_root_mean_squared_error: 1.6980 - val_y2_output_root_mean_squared_error: 2.9129
# Epoch 63/500
# 614/614 [==============================] - 0s 212us/sample - loss: 5.5189 - y1_output_loss: 1.8282 - y2_output_loss: 3.6530 - y1_output_root_mean_squared_error: 1.3569 - y2_output_root_mean_squared_error: 1.9177 - val_loss: 5.5754 - val_y1_output_loss: 1.6303 - val_y2_output_loss: 3.8325 - val_y1_output_root_mean_squared_error: 1.2917 - val_y2_output_root_mean_squared_error: 1.9766
# Epoch 64/500
# 614/614 [==============================] - 0s 190us/sample - loss: 4.8488 - y1_output_loss: 1.6673 - y2_output_loss: 3.1794 - y1_output_root_mean_squared_error: 1.2826 - y2_output_root_mean_squared_error: 1.7899 - val_loss: 6.5368 - val_y1_output_loss: 2.3203 - val_y2_output_loss: 4.3921 - val_y1_output_root_mean_squared_error: 1.5153 - val_y2_output_root_mean_squared_error: 2.0593
# Epoch 65/500
# 614/614 [==============================] - 0s 200us/sample - loss: 8.6823 - y1_output_loss: 2.7231 - y2_output_loss: 6.0210 - y1_output_root_mean_squared_error: 1.6411 - y2_output_root_mean_squared_error: 2.4473 - val_loss: 7.8875 - val_y1_output_loss: 3.1190 - val_y2_output_loss: 4.7582 - val_y1_output_root_mean_squared_error: 1.7800 - val_y2_output_root_mean_squared_error: 2.1724
# Epoch 66/500
# 614/614 [==============================] - 0s 224us/sample - loss: 6.7845 - y1_output_loss: 1.9467 - y2_output_loss: 4.7988 - y1_output_root_mean_squared_error: 1.4001 - y2_output_root_mean_squared_error: 2.1964 - val_loss: 11.6089 - val_y1_output_loss: 2.0853 - val_y2_output_loss: 9.1091 - val_y1_output_root_mean_squared_error: 1.4670 - val_y2_output_root_mean_squared_error: 3.0752
# Epoch 67/500
# 614/614 [==============================] - 0s 197us/sample - loss: 6.5243 - y1_output_loss: 1.9816 - y2_output_loss: 4.4877 - y1_output_root_mean_squared_error: 1.4129 - y2_output_root_mean_squared_error: 2.1279 - val_loss: 6.2601 - val_y1_output_loss: 2.2662 - val_y2_output_loss: 3.8421 - val_y1_output_root_mean_squared_error: 1.5290 - val_y2_output_root_mean_squared_error: 1.9804
# Epoch 68/500
# 614/614 [==============================] - 0s 196us/sample - loss: 5.1964 - y1_output_loss: 1.6471 - y2_output_loss: 3.5392 - y1_output_root_mean_squared_error: 1.2809 - y2_output_root_mean_squared_error: 1.8856 - val_loss: 9.2604 - val_y1_output_loss: 2.4908 - val_y2_output_loss: 6.8521 - val_y1_output_root_mean_squared_error: 1.5471 - val_y2_output_root_mean_squared_error: 2.6205
# Epoch 69/500
# 614/614 [==============================] - 0s 206us/sample - loss: 5.1856 - y1_output_loss: 1.7523 - y2_output_loss: 3.5038 - y1_output_root_mean_squared_error: 1.3164 - y2_output_root_mean_squared_error: 1.8581 - val_loss: 18.9505 - val_y1_output_loss: 4.5853 - val_y2_output_loss: 13.6910 - val_y1_output_root_mean_squared_error: 2.1783 - val_y2_output_root_mean_squared_error: 3.7690
# Epoch 70/500
# 614/614 [==============================] - 0s 201us/sample - loss: 4.6999 - y1_output_loss: 1.4487 - y2_output_loss: 3.2171 - y1_output_root_mean_squared_error: 1.2073 - y2_output_root_mean_squared_error: 1.8007 - val_loss: 4.8710 - val_y1_output_loss: 1.2965 - val_y2_output_loss: 3.4541 - val_y1_output_root_mean_squared_error: 1.1553 - val_y2_output_root_mean_squared_error: 1.8805
# Epoch 71/500
# 614/614 [==============================] - 0s 190us/sample - loss: 3.6940 - y1_output_loss: 1.3243 - y2_output_loss: 2.4602 - y1_output_root_mean_squared_error: 1.1352 - y2_output_root_mean_squared_error: 1.5509 - val_loss: 4.4391 - val_y1_output_loss: 1.2096 - val_y2_output_loss: 3.0846 - val_y1_output_root_mean_squared_error: 1.1193 - val_y2_output_root_mean_squared_error: 1.7850
# Epoch 72/500
# 614/614 [==============================] - 0s 193us/sample - loss: 4.0020 - y1_output_loss: 1.2229 - y2_output_loss: 2.7500 - y1_output_root_mean_squared_error: 1.1077 - y2_output_root_mean_squared_error: 1.6658 - val_loss: 4.1761 - val_y1_output_loss: 1.2269 - val_y2_output_loss: 2.9071 - val_y1_output_root_mean_squared_error: 1.1144 - val_y2_output_root_mean_squared_error: 1.7130
# Epoch 73/500
# 614/614 [==============================] - 0s 206us/sample - loss: 4.4703 - y1_output_loss: 1.3041 - y2_output_loss: 3.1961 - y1_output_root_mean_squared_error: 1.1348 - y2_output_root_mean_squared_error: 1.7840 - val_loss: 13.6737 - val_y1_output_loss: 4.6740 - val_y2_output_loss: 9.1073 - val_y1_output_root_mean_squared_error: 2.1701 - val_y2_output_root_mean_squared_error: 2.9941
# Epoch 74/500
# 614/614 [==============================] - 0s 206us/sample - loss: 8.4017 - y1_output_loss: 2.4519 - y2_output_loss: 5.8896 - y1_output_root_mean_squared_error: 1.5713 - y2_output_root_mean_squared_error: 2.4357 - val_loss: 6.0692 - val_y1_output_loss: 1.5018 - val_y2_output_loss: 4.3633 - val_y1_output_root_mean_squared_error: 1.2450 - val_y2_output_root_mean_squared_error: 2.1259
# Epoch 75/500
# 614/614 [==============================] - 0s 202us/sample - loss: 4.3005 - y1_output_loss: 1.3144 - y2_output_loss: 3.0586 - y1_output_root_mean_squared_error: 1.1497 - y2_output_root_mean_squared_error: 1.7259 - val_loss: 20.3719 - val_y1_output_loss: 2.1976 - val_y2_output_loss: 17.5794 - val_y1_output_root_mean_squared_error: 1.5050 - val_y2_output_root_mean_squared_error: 4.2552
# Epoch 76/500
# 614/614 [==============================] - 0s 267us/sample - loss: 3.5900 - y1_output_loss: 1.0192 - y2_output_loss: 2.5667 - y1_output_root_mean_squared_error: 1.0119 - y2_output_root_mean_squared_error: 1.6019 - val_loss: 14.7230 - val_y1_output_loss: 2.3256 - val_y2_output_loss: 11.8945 - val_y1_output_root_mean_squared_error: 1.5496 - val_y2_output_root_mean_squared_error: 3.5102
# Epoch 77/500
# 614/614 [==============================] - 0s 246us/sample - loss: 3.9146 - y1_output_loss: 1.1575 - y2_output_loss: 2.7461 - y1_output_root_mean_squared_error: 1.0794 - y2_output_root_mean_squared_error: 1.6582 - val_loss: 4.4522 - val_y1_output_loss: 1.0815 - val_y2_output_loss: 3.2620 - val_y1_output_root_mean_squared_error: 1.0477 - val_y2_output_root_mean_squared_error: 1.8315
# Epoch 78/500
# 614/614 [==============================] - 0s 244us/sample - loss: 5.0590 - y1_output_loss: 1.4657 - y2_output_loss: 3.7537 - y1_output_root_mean_squared_error: 1.1957 - y2_output_root_mean_squared_error: 1.9051 - val_loss: 9.1539 - val_y1_output_loss: 1.6256 - val_y2_output_loss: 7.1959 - val_y1_output_root_mean_squared_error: 1.2980 - val_y2_output_root_mean_squared_error: 2.7330
# Epoch 79/500
# 614/614 [==============================] - 0s 266us/sample - loss: 3.5082 - y1_output_loss: 1.0366 - y2_output_loss: 2.5033 - y1_output_root_mean_squared_error: 1.0118 - y2_output_root_mean_squared_error: 1.5762 - val_loss: 14.9079 - val_y1_output_loss: 2.6553 - val_y2_output_loss: 11.7521 - val_y1_output_root_mean_squared_error: 1.6579 - val_y2_output_root_mean_squared_error: 3.4870
# Epoch 80/500
# 614/614 [==============================] - 0s 284us/sample - loss: 3.1676 - y1_output_loss: 0.9191 - y2_output_loss: 2.2340 - y1_output_root_mean_squared_error: 0.9600 - y2_output_root_mean_squared_error: 1.4987 - val_loss: 4.7678 - val_y1_output_loss: 1.7943 - val_y2_output_loss: 2.9507 - val_y1_output_root_mean_squared_error: 1.3513 - val_y2_output_root_mean_squared_error: 1.7152
# Epoch 81/500
# 614/614 [==============================] - 0s 264us/sample - loss: 4.5444 - y1_output_loss: 1.2913 - y2_output_loss: 3.6038 - y1_output_root_mean_squared_error: 1.0999 - y2_output_root_mean_squared_error: 1.8261 - val_loss: 64.4234 - val_y1_output_loss: 18.2296 - val_y2_output_loss: 46.2573 - val_y1_output_root_mean_squared_error: 4.2810 - val_y2_output_root_mean_squared_error: 6.7894
# Epoch 82/500
# 614/614 [==============================] - 0s 265us/sample - loss: 4.9118 - y1_output_loss: 1.4849 - y2_output_loss: 3.3950 - y1_output_root_mean_squared_error: 1.2209 - y2_output_root_mean_squared_error: 1.8496 - val_loss: 4.8163 - val_y1_output_loss: 1.6312 - val_y2_output_loss: 3.1388 - val_y1_output_root_mean_squared_error: 1.2922 - val_y2_output_root_mean_squared_error: 1.7738
# Epoch 83/500
# 614/614 [==============================] - 0s 275us/sample - loss: 3.3351 - y1_output_loss: 0.9745 - y2_output_loss: 2.3574 - y1_output_root_mean_squared_error: 0.9891 - y2_output_root_mean_squared_error: 1.5352 - val_loss: 3.9593 - val_y1_output_loss: 1.1701 - val_y2_output_loss: 2.8345 - val_y1_output_root_mean_squared_error: 1.0708 - val_y2_output_root_mean_squared_error: 1.6771
# Epoch 84/500
# 614/614 [==============================] - 0s 237us/sample - loss: 3.2964 - y1_output_loss: 0.9283 - y2_output_loss: 2.3477 - y1_output_root_mean_squared_error: 0.9652 - y2_output_root_mean_squared_error: 1.5378 - val_loss: 5.4969 - val_y1_output_loss: 1.3126 - val_y2_output_loss: 4.0273 - val_y1_output_root_mean_squared_error: 1.1569 - val_y2_output_root_mean_squared_error: 2.0393
# Epoch 85/500
# 614/614 [==============================] - 0s 210us/sample - loss: 3.0925 - y1_output_loss: 0.9067 - y2_output_loss: 2.1600 - y1_output_root_mean_squared_error: 0.9563 - y2_output_root_mean_squared_error: 1.4758 - val_loss: 4.4462 - val_y1_output_loss: 1.6668 - val_y2_output_loss: 2.6900 - val_y1_output_root_mean_squared_error: 1.3085 - val_y2_output_root_mean_squared_error: 1.6535
# Epoch 86/500
# 614/614 [==============================] - 0s 203us/sample - loss: 3.1448 - y1_output_loss: 0.8917 - y2_output_loss: 2.2378 - y1_output_root_mean_squared_error: 0.9456 - y2_output_root_mean_squared_error: 1.5002 - val_loss: 4.5363 - val_y1_output_loss: 0.7538 - val_y2_output_loss: 3.6270 - val_y1_output_root_mean_squared_error: 0.8797 - val_y2_output_root_mean_squared_error: 1.9397
# Epoch 87/500
# 614/614 [==============================] - 0s 214us/sample - loss: 3.2120 - y1_output_loss: 0.8209 - y2_output_loss: 2.3964 - y1_output_root_mean_squared_error: 0.9073 - y2_output_root_mean_squared_error: 1.5456 - val_loss: 7.7943 - val_y1_output_loss: 2.9320 - val_y2_output_loss: 4.8139 - val_y1_output_root_mean_squared_error: 1.7282 - val_y2_output_root_mean_squared_error: 2.1926
# Epoch 88/500
# 614/614 [==============================] - 0s 209us/sample - loss: 3.5421 - y1_output_loss: 1.0684 - y2_output_loss: 2.5113 - y1_output_root_mean_squared_error: 1.0338 - y2_output_root_mean_squared_error: 1.5727 - val_loss: 4.2444 - val_y1_output_loss: 1.4422 - val_y2_output_loss: 2.7768 - val_y1_output_root_mean_squared_error: 1.2154 - val_y2_output_root_mean_squared_error: 1.6635
# Epoch 89/500
# 614/614 [==============================] - 0s 209us/sample - loss: 2.8684 - y1_output_loss: 0.7616 - y2_output_loss: 2.1087 - y1_output_root_mean_squared_error: 0.8690 - y2_output_root_mean_squared_error: 1.4537 - val_loss: 5.6404 - val_y1_output_loss: 0.7698 - val_y2_output_loss: 4.8960 - val_y1_output_root_mean_squared_error: 0.8866 - val_y2_output_root_mean_squared_error: 2.2032
# Epoch 90/500
# 614/614 [==============================] - 0s 250us/sample - loss: 4.3149 - y1_output_loss: 1.1450 - y2_output_loss: 3.1469 - y1_output_root_mean_squared_error: 1.0738 - y2_output_root_mean_squared_error: 1.7781 - val_loss: 3.7140 - val_y1_output_loss: 0.9103 - val_y2_output_loss: 2.6881 - val_y1_output_root_mean_squared_error: 0.9652 - val_y2_output_root_mean_squared_error: 1.6680
# Epoch 91/500
# 614/614 [==============================] - 0s 218us/sample - loss: 4.7581 - y1_output_loss: 1.3501 - y2_output_loss: 3.4024 - y1_output_root_mean_squared_error: 1.1636 - y2_output_root_mean_squared_error: 1.8450 - val_loss: 4.6242 - val_y1_output_loss: 1.5738 - val_y2_output_loss: 2.9611 - val_y1_output_root_mean_squared_error: 1.2751 - val_y2_output_root_mean_squared_error: 1.7316
# Epoch 92/500
# 614/614 [==============================] - 0s 196us/sample - loss: 2.6099 - y1_output_loss: 0.8243 - y2_output_loss: 1.7696 - y1_output_root_mean_squared_error: 0.9098 - y2_output_root_mean_squared_error: 1.3350 - val_loss: 3.3012 - val_y1_output_loss: 1.0405 - val_y2_output_loss: 2.2097 - val_y1_output_root_mean_squared_error: 1.0307 - val_y2_output_root_mean_squared_error: 1.4963
# Epoch 93/500
# 614/614 [==============================] - 0s 195us/sample - loss: 2.5244 - y1_output_loss: 0.6759 - y2_output_loss: 1.8305 - y1_output_root_mean_squared_error: 0.8251 - y2_output_root_mean_squared_error: 1.3578 - val_loss: 2.8636 - val_y1_output_loss: 0.6430 - val_y2_output_loss: 2.1599 - val_y1_output_root_mean_squared_error: 0.8121 - val_y2_output_root_mean_squared_error: 1.4846
# Epoch 94/500
# 614/614 [==============================] - 0s 205us/sample - loss: 2.4591 - y1_output_loss: 0.6665 - y2_output_loss: 1.7981 - y1_output_root_mean_squared_error: 0.8176 - y2_output_root_mean_squared_error: 1.3381 - val_loss: 6.8034 - val_y1_output_loss: 1.2206 - val_y2_output_loss: 5.4046 - val_y1_output_root_mean_squared_error: 1.1147 - val_y2_output_root_mean_squared_error: 2.3581
# Epoch 95/500
# 614/614 [==============================] - 0s 204us/sample - loss: 4.2936 - y1_output_loss: 1.0648 - y2_output_loss: 3.2276 - y1_output_root_mean_squared_error: 1.0358 - y2_output_root_mean_squared_error: 1.7946 - val_loss: 3.1901 - val_y1_output_loss: 0.8890 - val_y2_output_loss: 2.2379 - val_y1_output_root_mean_squared_error: 0.9539 - val_y2_output_root_mean_squared_error: 1.5100
# Epoch 96/500
# 614/614 [==============================] - 0s 211us/sample - loss: 3.3373 - y1_output_loss: 0.8967 - y2_output_loss: 2.4584 - y1_output_root_mean_squared_error: 0.9349 - y2_output_root_mean_squared_error: 1.5695 - val_loss: 3.9252 - val_y1_output_loss: 1.3293 - val_y2_output_loss: 2.5269 - val_y1_output_root_mean_squared_error: 1.1622 - val_y2_output_root_mean_squared_error: 1.6045
# Epoch 97/500
# 614/614 [==============================] - 0s 255us/sample - loss: 2.7334 - y1_output_loss: 0.8025 - y2_output_loss: 1.9336 - y1_output_root_mean_squared_error: 0.8991 - y2_output_root_mean_squared_error: 1.3874 - val_loss: 5.3497 - val_y1_output_loss: 0.5425 - val_y2_output_loss: 4.6281 - val_y1_output_root_mean_squared_error: 0.7449 - val_y2_output_root_mean_squared_error: 2.1897
# Epoch 98/500
# 614/614 [==============================] - 0s 223us/sample - loss: 3.5267 - y1_output_loss: 1.0447 - y2_output_loss: 2.4609 - y1_output_root_mean_squared_error: 1.0238 - y2_output_root_mean_squared_error: 1.5744 - val_loss: 2.9149 - val_y1_output_loss: 0.7955 - val_y2_output_loss: 2.0913 - val_y1_output_root_mean_squared_error: 0.9056 - val_y2_output_root_mean_squared_error: 1.4474
# Epoch 99/500
# 614/614 [==============================] - 0s 252us/sample - loss: 4.5039 - y1_output_loss: 1.3446 - y2_output_loss: 3.1731 - y1_output_root_mean_squared_error: 1.1585 - y2_output_root_mean_squared_error: 1.7781 - val_loss: 14.8661 - val_y1_output_loss: 4.2144 - val_y2_output_loss: 10.3761 - val_y1_output_root_mean_squared_error: 2.0689 - val_y2_output_root_mean_squared_error: 3.2536
# Epoch 100/500
# 614/614 [==============================] - 0s 215us/sample - loss: 4.0404 - y1_output_loss: 1.0992 - y2_output_loss: 2.9174 - y1_output_root_mean_squared_error: 1.0508 - y2_output_root_mean_squared_error: 1.7135 - val_loss: 3.8714 - val_y1_output_loss: 0.9301 - val_y2_output_loss: 2.8180 - val_y1_output_root_mean_squared_error: 0.9789 - val_y2_output_root_mean_squared_error: 1.7068
# Epoch 101/500
# 614/614 [==============================] - 0s 230us/sample - loss: 2.4740 - y1_output_loss: 0.7290 - y2_output_loss: 1.7400 - y1_output_root_mean_squared_error: 0.8557 - y2_output_root_mean_squared_error: 1.3198 - val_loss: 3.5101 - val_y1_output_loss: 0.8627 - val_y2_output_loss: 2.5275 - val_y1_output_root_mean_squared_error: 0.9431 - val_y2_output_root_mean_squared_error: 1.6189
# Epoch 102/500
# 614/614 [==============================] - 0s 215us/sample - loss: 2.1237 - y1_output_loss: 0.5293 - y2_output_loss: 1.5922 - y1_output_root_mean_squared_error: 0.7235 - y2_output_root_mean_squared_error: 1.2650 - val_loss: 4.7079 - val_y1_output_loss: 0.9091 - val_y2_output_loss: 3.6368 - val_y1_output_root_mean_squared_error: 0.9680 - val_y2_output_root_mean_squared_error: 1.9418
# Epoch 103/500
# 614/614 [==============================] - 0s 191us/sample - loss: 2.2981 - y1_output_loss: 0.5807 - y2_output_loss: 1.7208 - y1_output_root_mean_squared_error: 0.7646 - y2_output_root_mean_squared_error: 1.3090 - val_loss: 6.3429 - val_y1_output_loss: 2.2003 - val_y2_output_loss: 4.0704 - val_y1_output_root_mean_squared_error: 1.4980 - val_y2_output_root_mean_squared_error: 2.0245
# Epoch 104/500
# 614/614 [==============================] - 0s 263us/sample - loss: 3.9714 - y1_output_loss: 1.0075 - y2_output_loss: 2.9556 - y1_output_root_mean_squared_error: 1.0083 - y2_output_root_mean_squared_error: 1.7189 - val_loss: 2.6187 - val_y1_output_loss: 0.5391 - val_y2_output_loss: 2.0113 - val_y1_output_root_mean_squared_error: 0.7426 - val_y2_output_root_mean_squared_error: 1.4378
# Epoch 105/500
# 614/614 [==============================] - 0s 227us/sample - loss: 3.6817 - y1_output_loss: 1.0596 - y2_output_loss: 2.6106 - y1_output_root_mean_squared_error: 1.0336 - y2_output_root_mean_squared_error: 1.6166 - val_loss: 4.7019 - val_y1_output_loss: 0.6188 - val_y2_output_loss: 3.9251 - val_y1_output_root_mean_squared_error: 0.7980 - val_y2_output_root_mean_squared_error: 2.0162
# Epoch 106/500
# 614/614 [==============================] - 0s 245us/sample - loss: 2.4109 - y1_output_loss: 0.6201 - y2_output_loss: 1.8213 - y1_output_root_mean_squared_error: 0.7867 - y2_output_root_mean_squared_error: 1.3387 - val_loss: 12.4162 - val_y1_output_loss: 1.1056 - val_y2_output_loss: 10.9482 - val_y1_output_root_mean_squared_error: 1.0674 - val_y2_output_root_mean_squared_error: 3.3581
# Epoch 107/500
# 614/614 [==============================] - 0s 208us/sample - loss: 3.8437 - y1_output_loss: 1.0471 - y2_output_loss: 2.7918 - y1_output_root_mean_squared_error: 1.0216 - y2_output_root_mean_squared_error: 1.6733 - val_loss: 4.7310 - val_y1_output_loss: 0.5130 - val_y2_output_loss: 4.0448 - val_y1_output_root_mean_squared_error: 0.7285 - val_y2_output_root_mean_squared_error: 2.0494
# Epoch 108/500
# 614/614 [==============================] - 0s 205us/sample - loss: 2.1678 - y1_output_loss: 0.5522 - y2_output_loss: 1.5969 - y1_output_root_mean_squared_error: 0.7462 - y2_output_root_mean_squared_error: 1.2692 - val_loss: 2.6286 - val_y1_output_loss: 0.6413 - val_y2_output_loss: 1.9170 - val_y1_output_root_mean_squared_error: 0.8103 - val_y2_output_root_mean_squared_error: 1.4043
# Epoch 109/500
# 614/614 [==============================] - 0s 214us/sample - loss: 1.8664 - y1_output_loss: 0.4920 - y2_output_loss: 1.3762 - y1_output_root_mean_squared_error: 0.7029 - y2_output_root_mean_squared_error: 1.1715 - val_loss: 2.8867 - val_y1_output_loss: 0.6980 - val_y2_output_loss: 2.1947 - val_y1_output_root_mean_squared_error: 0.8350 - val_y2_output_root_mean_squared_error: 1.4797
# Epoch 110/500
# 614/614 [==============================] - 0s 206us/sample - loss: 2.0421 - y1_output_loss: 0.5147 - y2_output_loss: 1.5105 - y1_output_root_mean_squared_error: 0.7204 - y2_output_root_mean_squared_error: 1.2341 - val_loss: 3.2049 - val_y1_output_loss: 0.5310 - val_y2_output_loss: 2.5805 - val_y1_output_root_mean_squared_error: 0.7347 - val_y2_output_root_mean_squared_error: 1.6325
# Epoch 111/500
# 614/614 [==============================] - 0s 233us/sample - loss: 2.3802 - y1_output_loss: 0.7140 - y2_output_loss: 1.6793 - y1_output_root_mean_squared_error: 0.8481 - y2_output_root_mean_squared_error: 1.2887 - val_loss: 5.9080 - val_y1_output_loss: 1.7757 - val_y2_output_loss: 4.0357 - val_y1_output_root_mean_squared_error: 1.3501 - val_y2_output_root_mean_squared_error: 2.0212
# Epoch 112/500
# 614/614 [==============================] - 0s 225us/sample - loss: 3.2898 - y1_output_loss: 0.8011 - y2_output_loss: 2.4664 - y1_output_root_mean_squared_error: 0.8982 - y2_output_root_mean_squared_error: 1.5757 - val_loss: 2.6639 - val_y1_output_loss: 0.7107 - val_y2_output_loss: 1.9018 - val_y1_output_root_mean_squared_error: 0.8502 - val_y2_output_root_mean_squared_error: 1.3932
# Epoch 113/500
# 614/614 [==============================] - 0s 198us/sample - loss: 2.2194 - y1_output_loss: 0.4983 - y2_output_loss: 1.7174 - y1_output_root_mean_squared_error: 0.7088 - y2_output_root_mean_squared_error: 1.3103 - val_loss: 6.5895 - val_y1_output_loss: 0.8152 - val_y2_output_loss: 5.5631 - val_y1_output_root_mean_squared_error: 0.9113 - val_y2_output_root_mean_squared_error: 2.3998
# Epoch 114/500
# 614/614 [==============================] - 0s 205us/sample - loss: 2.9706 - y1_output_loss: 0.8237 - y2_output_loss: 2.1492 - y1_output_root_mean_squared_error: 0.9051 - y2_output_root_mean_squared_error: 1.4668 - val_loss: 3.0004 - val_y1_output_loss: 0.6286 - val_y2_output_loss: 2.3411 - val_y1_output_root_mean_squared_error: 0.8049 - val_y2_output_root_mean_squared_error: 1.5338
# Epoch 115/500
# 614/614 [==============================] - 0s 191us/sample - loss: 2.6695 - y1_output_loss: 0.6864 - y2_output_loss: 1.9624 - y1_output_root_mean_squared_error: 0.8316 - y2_output_root_mean_squared_error: 1.4064 - val_loss: 2.4940 - val_y1_output_loss: 0.6572 - val_y2_output_loss: 1.7845 - val_y1_output_root_mean_squared_error: 0.8208 - val_y2_output_root_mean_squared_error: 1.3492
# Epoch 116/500
# 614/614 [==============================] - 0s 277us/sample - loss: 2.1066 - y1_output_loss: 0.5126 - y2_output_loss: 1.6389 - y1_output_root_mean_squared_error: 0.7100 - y2_output_root_mean_squared_error: 1.2659 - val_loss: 8.7375 - val_y1_output_loss: 2.7880 - val_y2_output_loss: 5.9620 - val_y1_output_root_mean_squared_error: 1.6769 - val_y2_output_root_mean_squared_error: 2.4342
# Epoch 117/500
# 614/614 [==============================] - 0s 196us/sample - loss: 3.0922 - y1_output_loss: 0.7506 - y2_output_loss: 2.3399 - y1_output_root_mean_squared_error: 0.8692 - y2_output_root_mean_squared_error: 1.5286 - val_loss: 3.7568 - val_y1_output_loss: 0.6251 - val_y2_output_loss: 3.0067 - val_y1_output_root_mean_squared_error: 0.8018 - val_y2_output_root_mean_squared_error: 1.7646
# Epoch 118/500
# 614/614 [==============================] - 0s 256us/sample - loss: 2.1821 - y1_output_loss: 0.4979 - y2_output_loss: 1.6967 - y1_output_root_mean_squared_error: 0.7043 - y2_output_root_mean_squared_error: 1.2985 - val_loss: 5.4954 - val_y1_output_loss: 0.9315 - val_y2_output_loss: 4.3717 - val_y1_output_root_mean_squared_error: 0.9816 - val_y2_output_root_mean_squared_error: 2.1288
# Epoch 119/500
# 614/614 [==============================] - 0s 247us/sample - loss: 3.3574 - y1_output_loss: 0.7994 - y2_output_loss: 2.5751 - y1_output_root_mean_squared_error: 0.8952 - y2_output_root_mean_squared_error: 1.5987 - val_loss: 5.6276 - val_y1_output_loss: 0.9577 - val_y2_output_loss: 4.6751 - val_y1_output_root_mean_squared_error: 0.9873 - val_y2_output_root_mean_squared_error: 2.1571
# Epoch 120/500
# 614/614 [==============================] - 0s 266us/sample - loss: 4.0124 - y1_output_loss: 1.0073 - y2_output_loss: 2.9712 - y1_output_root_mean_squared_error: 1.0082 - y2_output_root_mean_squared_error: 1.7309 - val_loss: 2.5754 - val_y1_output_loss: 0.4690 - val_y2_output_loss: 2.0122 - val_y1_output_root_mean_squared_error: 0.6964 - val_y2_output_root_mean_squared_error: 1.4458
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 194us/sample - loss: 0.6558 - y1_output_loss: 0.1699 - y2_output_loss: 0.4950 - y1_output_root_mean_squared_error: 0.4082 - y2_output_root_mean_squared_error: 0.6994 - val_loss: 2.0725 - val_y1_output_loss: 0.2933 - val_y2_output_loss: 1.7097 - val_y1_output_root_mean_squared_error: 0.5461 - val_y2_output_root_mean_squared_error: 1.3320
# Epoch 462/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.5282 - y1_output_loss: 0.1480 - y2_output_loss: 0.3766 - y1_output_root_mean_squared_error: 0.3859 - y2_output_root_mean_squared_error: 0.6158 - val_loss: 0.8900 - val_y1_output_loss: 0.1512 - val_y2_output_loss: 0.7224 - val_y1_output_root_mean_squared_error: 0.3851 - val_y2_output_root_mean_squared_error: 0.8612
# Epoch 463/500
# 614/614 [==============================] - 0s 184us/sample - loss: 0.4568 - y1_output_loss: 0.1522 - y2_output_loss: 0.3082 - y1_output_root_mean_squared_error: 0.3836 - y2_output_root_mean_squared_error: 0.5564 - val_loss: 2.0752 - val_y1_output_loss: 0.9084 - val_y2_output_loss: 1.1175 - val_y1_output_root_mean_squared_error: 0.9646 - val_y2_output_root_mean_squared_error: 1.0699
# Epoch 464/500
# 614/614 [==============================] - 0s 187us/sample - loss: 0.6295 - y1_output_loss: 0.1804 - y2_output_loss: 0.4457 - y1_output_root_mean_squared_error: 0.4265 - y2_output_root_mean_squared_error: 0.6691 - val_loss: 0.8050 - val_y1_output_loss: 0.1650 - val_y2_output_loss: 0.6248 - val_y1_output_root_mean_squared_error: 0.4058 - val_y2_output_root_mean_squared_error: 0.8002
# Epoch 465/500
# 614/614 [==============================] - 0s 214us/sample - loss: 0.4739 - y1_output_loss: 0.1493 - y2_output_loss: 0.3218 - y1_output_root_mean_squared_error: 0.3874 - y2_output_root_mean_squared_error: 0.5691 - val_loss: 0.8215 - val_y1_output_loss: 0.1431 - val_y2_output_loss: 0.6562 - val_y1_output_root_mean_squared_error: 0.3790 - val_y2_output_root_mean_squared_error: 0.8234
# Epoch 466/500
# 614/614 [==============================] - 0s 205us/sample - loss: 0.4550 - y1_output_loss: 0.1365 - y2_output_loss: 0.3179 - y1_output_root_mean_squared_error: 0.3679 - y2_output_root_mean_squared_error: 0.5654 - val_loss: 0.9446 - val_y1_output_loss: 0.2238 - val_y2_output_loss: 0.6956 - val_y1_output_root_mean_squared_error: 0.4754 - val_y2_output_root_mean_squared_error: 0.8477
# Epoch 467/500
# 614/614 [==============================] - 0s 202us/sample - loss: 0.6574 - y1_output_loss: 0.1587 - y2_output_loss: 0.4952 - y1_output_root_mean_squared_error: 0.3997 - y2_output_root_mean_squared_error: 0.7055 - val_loss: 0.8514 - val_y1_output_loss: 0.1710 - val_y2_output_loss: 0.6549 - val_y1_output_root_mean_squared_error: 0.4160 - val_y2_output_root_mean_squared_error: 0.8236
# Epoch 468/500
# 614/614 [==============================] - 0s 246us/sample - loss: 0.5227 - y1_output_loss: 0.1675 - y2_output_loss: 0.3608 - y1_output_root_mean_squared_error: 0.4062 - y2_output_root_mean_squared_error: 0.5981 - val_loss: 1.5485 - val_y1_output_loss: 0.5820 - val_y2_output_loss: 0.9606 - val_y1_output_root_mean_squared_error: 0.7660 - val_y2_output_root_mean_squared_error: 0.9807
# Epoch 469/500
# 614/614 [==============================] - 0s 244us/sample - loss: 0.5536 - y1_output_loss: 0.1759 - y2_output_loss: 0.3834 - y1_output_root_mean_squared_error: 0.4160 - y2_output_root_mean_squared_error: 0.6170 - val_loss: 1.8143 - val_y1_output_loss: 0.5944 - val_y2_output_loss: 1.2267 - val_y1_output_root_mean_squared_error: 0.7619 - val_y2_output_root_mean_squared_error: 1.1108
# Epoch 470/500
# 614/614 [==============================] - 0s 338us/sample - loss: 0.5066 - y1_output_loss: 0.1447 - y2_output_loss: 0.3587 - y1_output_root_mean_squared_error: 0.3806 - y2_output_root_mean_squared_error: 0.6014 - val_loss: 0.7595 - val_y1_output_loss: 0.1416 - val_y2_output_loss: 0.6067 - val_y1_output_root_mean_squared_error: 0.3740 - val_y2_output_root_mean_squared_error: 0.7872
# Epoch 471/500
# 614/614 [==============================] - 0s 284us/sample - loss: 0.3897 - y1_output_loss: 0.1119 - y2_output_loss: 0.2787 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.5262 - val_loss: 1.0739 - val_y1_output_loss: 0.1218 - val_y2_output_loss: 0.9236 - val_y1_output_root_mean_squared_error: 0.3471 - val_y2_output_root_mean_squared_error: 0.9765
# Epoch 472/500
# 614/614 [==============================] - 0s 241us/sample - loss: 0.4833 - y1_output_loss: 0.1503 - y2_output_loss: 0.3292 - y1_output_root_mean_squared_error: 0.3895 - y2_output_root_mean_squared_error: 0.5759 - val_loss: 1.1723 - val_y1_output_loss: 0.3238 - val_y2_output_loss: 0.8239 - val_y1_output_root_mean_squared_error: 0.5733 - val_y2_output_root_mean_squared_error: 0.9185
# Epoch 473/500
# 614/614 [==============================] - 0s 224us/sample - loss: 0.4767 - y1_output_loss: 0.1380 - y2_output_loss: 0.3398 - y1_output_root_mean_squared_error: 0.3702 - y2_output_root_mean_squared_error: 0.5828 - val_loss: 0.8244 - val_y1_output_loss: 0.1605 - val_y2_output_loss: 0.6439 - val_y1_output_root_mean_squared_error: 0.4022 - val_y2_output_root_mean_squared_error: 0.8140
# Epoch 474/500
# 614/614 [==============================] - 0s 250us/sample - loss: 0.4632 - y1_output_loss: 0.1238 - y2_output_loss: 0.3416 - y1_output_root_mean_squared_error: 0.3519 - y2_output_root_mean_squared_error: 0.5825 - val_loss: 1.0031 - val_y1_output_loss: 0.2474 - val_y2_output_loss: 0.7311 - val_y1_output_root_mean_squared_error: 0.5018 - val_y2_output_root_mean_squared_error: 0.8668
# Epoch 475/500
# 614/614 [==============================] - 0s 215us/sample - loss: 0.4291 - y1_output_loss: 0.1235 - y2_output_loss: 0.3021 - y1_output_root_mean_squared_error: 0.3531 - y2_output_root_mean_squared_error: 0.5518 - val_loss: 0.8161 - val_y1_output_loss: 0.1251 - val_y2_output_loss: 0.6702 - val_y1_output_root_mean_squared_error: 0.3543 - val_y2_output_root_mean_squared_error: 0.8310
# Epoch 476/500
# 614/614 [==============================] - 0s 193us/sample - loss: 0.4435 - y1_output_loss: 0.1196 - y2_output_loss: 0.3267 - y1_output_root_mean_squared_error: 0.3472 - y2_output_root_mean_squared_error: 0.5683 - val_loss: 1.2898 - val_y1_output_loss: 0.1516 - val_y2_output_loss: 1.1595 - val_y1_output_root_mean_squared_error: 0.3872 - val_y2_output_root_mean_squared_error: 1.0677
# Epoch 477/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.4375 - y1_output_loss: 0.1302 - y2_output_loss: 0.3050 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5542 - val_loss: 1.2824 - val_y1_output_loss: 0.1318 - val_y2_output_loss: 1.1161 - val_y1_output_root_mean_squared_error: 0.3620 - val_y2_output_root_mean_squared_error: 1.0730
# Epoch 478/500
# 614/614 [==============================] - 0s 220us/sample - loss: 0.4800 - y1_output_loss: 0.1548 - y2_output_loss: 0.3244 - y1_output_root_mean_squared_error: 0.3949 - y2_output_root_mean_squared_error: 0.5693 - val_loss: 1.3289 - val_y1_output_loss: 0.3604 - val_y2_output_loss: 0.9407 - val_y1_output_root_mean_squared_error: 0.6044 - val_y2_output_root_mean_squared_error: 0.9816
# Epoch 479/500
# 614/614 [==============================] - 0s 222us/sample - loss: 0.5082 - y1_output_loss: 0.1303 - y2_output_loss: 0.3787 - y1_output_root_mean_squared_error: 0.3594 - y2_output_root_mean_squared_error: 0.6157 - val_loss: 0.9261 - val_y1_output_loss: 0.1708 - val_y2_output_loss: 0.7277 - val_y1_output_root_mean_squared_error: 0.4156 - val_y2_output_root_mean_squared_error: 0.8680
# Epoch 480/500
# 614/614 [==============================] - 0s 207us/sample - loss: 0.5387 - y1_output_loss: 0.1491 - y2_output_loss: 0.3931 - y1_output_root_mean_squared_error: 0.3869 - y2_output_root_mean_squared_error: 0.6237 - val_loss: 1.0644 - val_y1_output_loss: 0.2394 - val_y2_output_loss: 0.8099 - val_y1_output_root_mean_squared_error: 0.4932 - val_y2_output_root_mean_squared_error: 0.9062
# Epoch 481/500
# 614/614 [==============================] - 0s 193us/sample - loss: 0.5030 - y1_output_loss: 0.1482 - y2_output_loss: 0.3529 - y1_output_root_mean_squared_error: 0.3851 - y2_output_root_mean_squared_error: 0.5956 - val_loss: 1.1495 - val_y1_output_loss: 0.1668 - val_y2_output_loss: 0.9535 - val_y1_output_root_mean_squared_error: 0.4063 - val_y2_output_root_mean_squared_error: 0.9922
# Epoch 482/500
# 614/614 [==============================] - 0s 217us/sample - loss: 0.4444 - y1_output_loss: 0.1252 - y2_output_loss: 0.3198 - y1_output_root_mean_squared_error: 0.3519 - y2_output_root_mean_squared_error: 0.5662 - val_loss: 1.0000 - val_y1_output_loss: 0.2557 - val_y2_output_loss: 0.7349 - val_y1_output_root_mean_squared_error: 0.5061 - val_y2_output_root_mean_squared_error: 0.8625
# Epoch 483/500
# 614/614 [==============================] - 0s 199us/sample - loss: 0.4320 - y1_output_loss: 0.1365 - y2_output_loss: 0.2966 - y1_output_root_mean_squared_error: 0.3708 - y2_output_root_mean_squared_error: 0.5427 - val_loss: 0.9931 - val_y1_output_loss: 0.1365 - val_y2_output_loss: 0.8290 - val_y1_output_root_mean_squared_error: 0.3686 - val_y2_output_root_mean_squared_error: 0.9259
# Epoch 484/500
# 614/614 [==============================] - 0s 201us/sample - loss: 0.3580 - y1_output_loss: 0.1134 - y2_output_loss: 0.2433 - y1_output_root_mean_squared_error: 0.3380 - y2_output_root_mean_squared_error: 0.4937 - val_loss: 1.2829 - val_y1_output_loss: 0.1418 - val_y2_output_loss: 1.1005 - val_y1_output_root_mean_squared_error: 0.3773 - val_y2_output_root_mean_squared_error: 1.0680
# Epoch 485/500
# 614/614 [==============================] - 0s 217us/sample - loss: 0.4516 - y1_output_loss: 0.1263 - y2_output_loss: 0.3245 - y1_output_root_mean_squared_error: 0.3559 - y2_output_root_mean_squared_error: 0.5701 - val_loss: 0.9602 - val_y1_output_loss: 0.1330 - val_y2_output_loss: 0.8019 - val_y1_output_root_mean_squared_error: 0.3626 - val_y2_output_root_mean_squared_error: 0.9104
# Epoch 486/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.4070 - y1_output_loss: 0.1279 - y2_output_loss: 0.2770 - y1_output_root_mean_squared_error: 0.3585 - y2_output_root_mean_squared_error: 0.5277 - val_loss: 0.8419 - val_y1_output_loss: 0.1485 - val_y2_output_loss: 0.6734 - val_y1_output_root_mean_squared_error: 0.3859 - val_y2_output_root_mean_squared_error: 0.8324
# Epoch 487/500
# 614/614 [==============================] - 0s 199us/sample - loss: 0.3715 - y1_output_loss: 0.1210 - y2_output_loss: 0.2527 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5029 - val_loss: 1.5297 - val_y1_output_loss: 0.3677 - val_y2_output_loss: 1.1131 - val_y1_output_root_mean_squared_error: 0.6129 - val_y2_output_root_mean_squared_error: 1.0743
# Epoch 488/500
# 614/614 [==============================] - 0s 198us/sample - loss: 0.4545 - y1_output_loss: 0.1323 - y2_output_loss: 0.3192 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.5665 - val_loss: 1.6556 - val_y1_output_loss: 0.1677 - val_y2_output_loss: 1.4458 - val_y1_output_root_mean_squared_error: 0.4109 - val_y2_output_root_mean_squared_error: 1.2193
# Epoch 489/500
# 614/614 [==============================] - 0s 220us/sample - loss: 0.4420 - y1_output_loss: 0.1224 - y2_output_loss: 0.3260 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.5649 - val_loss: 1.5053 - val_y1_output_loss: 0.2126 - val_y2_output_loss: 1.2635 - val_y1_output_root_mean_squared_error: 0.4608 - val_y2_output_root_mean_squared_error: 1.1371
# Epoch 490/500
# 614/614 [==============================] - 0s 212us/sample - loss: 0.4346 - y1_output_loss: 0.1291 - y2_output_loss: 0.3066 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5519 - val_loss: 0.8642 - val_y1_output_loss: 0.1394 - val_y2_output_loss: 0.7071 - val_y1_output_root_mean_squared_error: 0.3719 - val_y2_output_root_mean_squared_error: 0.8520
# Epoch 491/500
# 614/614 [==============================] - 0s 222us/sample - loss: 0.4482 - y1_output_loss: 0.1269 - y2_output_loss: 0.3232 - y1_output_root_mean_squared_error: 0.3571 - y2_output_root_mean_squared_error: 0.5662 - val_loss: 1.0014 - val_y1_output_loss: 0.1554 - val_y2_output_loss: 0.8182 - val_y1_output_root_mean_squared_error: 0.3945 - val_y2_output_root_mean_squared_error: 0.9197
# Epoch 492/500
# 614/614 [==============================] - 0s 242us/sample - loss: 0.4571 - y1_output_loss: 0.1360 - y2_output_loss: 0.3195 - y1_output_root_mean_squared_error: 0.3689 - y2_output_root_mean_squared_error: 0.5666 - val_loss: 0.9444 - val_y1_output_loss: 0.1684 - val_y2_output_loss: 0.7471 - val_y1_output_root_mean_squared_error: 0.4120 - val_y2_output_root_mean_squared_error: 0.8801
# Epoch 493/500
# 614/614 [==============================] - 0s 215us/sample - loss: 0.4112 - y1_output_loss: 0.1169 - y2_output_loss: 0.2924 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.5430 - val_loss: 0.7903 - val_y1_output_loss: 0.1400 - val_y2_output_loss: 0.6265 - val_y1_output_root_mean_squared_error: 0.3757 - val_y2_output_root_mean_squared_error: 0.8057
# Epoch 494/500
# 614/614 [==============================] - 0s 247us/sample - loss: 0.3489 - y1_output_loss: 0.1181 - y2_output_loss: 0.2299 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.4804 - val_loss: 0.8150 - val_y1_output_loss: 0.1397 - val_y2_output_loss: 0.6607 - val_y1_output_root_mean_squared_error: 0.3705 - val_y2_output_root_mean_squared_error: 0.8233
# Epoch 495/500
# 614/614 [==============================] - 0s 229us/sample - loss: 1.0852 - y1_output_loss: 0.3101 - y2_output_loss: 0.7671 - y1_output_root_mean_squared_error: 0.5592 - y2_output_root_mean_squared_error: 0.8789 - val_loss: 0.7505 - val_y1_output_loss: 0.1321 - val_y2_output_loss: 0.6060 - val_y1_output_root_mean_squared_error: 0.3634 - val_y2_output_root_mean_squared_error: 0.7864
# Epoch 496/500
# 614/614 [==============================] - 0s 255us/sample - loss: 0.4147 - y1_output_loss: 0.1204 - y2_output_loss: 0.2909 - y1_output_root_mean_squared_error: 0.3484 - y2_output_root_mean_squared_error: 0.5416 - val_loss: 0.7652 - val_y1_output_loss: 0.1382 - val_y2_output_loss: 0.6144 - val_y1_output_root_mean_squared_error: 0.3706 - val_y2_output_root_mean_squared_error: 0.7924
# Epoch 497/500
# 614/614 [==============================] - 0s 242us/sample - loss: 0.3744 - y1_output_loss: 0.1170 - y2_output_loss: 0.2548 - y1_output_root_mean_squared_error: 0.3430 - y2_output_root_mean_squared_error: 0.5066 - val_loss: 0.8968 - val_y1_output_loss: 0.2312 - val_y2_output_loss: 0.6577 - val_y1_output_root_mean_squared_error: 0.4749 - val_y2_output_root_mean_squared_error: 0.8193
# Epoch 498/500
# 614/614 [==============================] - 0s 224us/sample - loss: 0.4726 - y1_output_loss: 0.1305 - y2_output_loss: 0.3416 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.5840 - val_loss: 1.2981 - val_y1_output_loss: 0.1617 - val_y2_output_loss: 1.0982 - val_y1_output_root_mean_squared_error: 0.4031 - val_y2_output_root_mean_squared_error: 1.0656
# Epoch 499/500
# 614/614 [==============================] - 0s 216us/sample - loss: 0.3786 - y1_output_loss: 0.1227 - y2_output_loss: 0.2530 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.5053 - val_loss: 0.7631 - val_y1_output_loss: 0.1323 - val_y2_output_loss: 0.6100 - val_y1_output_root_mean_squared_error: 0.3647 - val_y2_output_root_mean_squared_error: 0.7938
# Epoch 500/500
# 614/614 [==============================] - 0s 208us/sample - loss: 0.3325 - y1_output_loss: 0.1206 - y2_output_loss: 0.2152 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.4626 - val_loss: 0.9748 - val_y1_output_loss: 0.1853 - val_y2_output_loss: 0.7635 - val_y1_output_root_mean_squared_error: 0.4297 - val_y2_output_root_mean_squared_error: 0.8889

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 51us/sample - loss: 0.9748 - y1_output_loss: 0.1878 - y2_output_loss: 0.7871 - y1_output_root_mean_squared_error: 0.4297 - y2_output_root_mean_squared_error: 0.8889
# Loss = 0.974781499280558, Y1_loss = 0.18777303397655487, Y1_mse = 0.42971622943878174, Y2_loss = 0.7870500683784485, Y2_mse = 0.8888900279998779

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
